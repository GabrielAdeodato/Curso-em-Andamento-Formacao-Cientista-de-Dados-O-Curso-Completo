# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as srn
import statistics as sts

# %%
base = pd.read_csv('dados.csv', sep=';')
base.shape
# Out:
# (187, 4)

# %%
base.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
base.isnull().sum()
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
base.loc[(base['VALOREMPENHO'] <  base['PIB'] )]
# Out:
#      CODIGO                MUNICIPIO       PIB  VALOREMPENHO
# 169     329               VILA MARIA  31104.22      28149.89
# 171     284          IPIRANGA DO SUL  25276.04      22470.03
# 172     186                   CONDOR  25915.70      22632.98
# 173     109              SANTA MARIA  15719.56       9538.34
# 174     151              TUPANCIRETA  23275.79      12475.20
# 175      96             PORTO ALEGRE  30524.80       9358.33
# 176     108        SANTA CRUZ DO SUL  40671.53       9637.00
# 177      65                     IJUI  23027.95       5920.00
# 178     129                 SAO SEPE  15525.66       1186.00
# 179     372              MATO LEITAO  17213.98        760.00
# 180     372  SANTA VITORIA DO PALMAR  17213.98        760.00
# 181     372              MATO LEITAO  27170.89        760.00
# 182     372  SANTA VITORIA DO PALMAR  27170.89        760.00
# 183     107     SANTA BARBARA DO SUL  29654.02        365.00
# ...

# %%
srn.histplot(base.PIB, kde=True, bins=10).set(title='PIB')
# Out:
# [Text(0.5, 1.0, 'PIB')]

# %%
srn.histplot(base.VALOREMPENHO, kde=True, bins=10).set(title='Valor Empenhado')
# Out:
# [Text(0.5, 1.0, 'Valor Empenhado')]

# %%
agrupado = base.groupby(['MUNICIPIO'])['PIB'].sum()
agrupado
# Out:
# MUNICIPIO
# AGUDO                         16444.80
# AJURICABA                     20784.67
# ALECRIM                       11431.18
# ALMIRANTE TAMANDARE DO SUL    26895.37
# ALTO FELIZ                    13209.54
#                                 ...
# VERA CRUZ                     18417.96
# VIADUTOS                      12520.25
# VICTOR GRAEFF                 26700.28
# VILA MARIA                    31104.22
# VILA NOVA DO SUL              13053.13
# Name: PIB, Length: 177, dtype: float64

# %%
#grafico inútil por não conseguir ler
agrupado.plot.bar(color = 'gray')
# Out:
# <Axes: xlabel='MUNICIPIO'>

# %%
srn.regplot(x=base.VALOREMPENHO, y=base.PIB, data = base, x_jitter = 0.5, fit_reg = True)
# Out:
# <Axes: xlabel='VALOREMPENHO', ylabel='PIB'>

# %%
base.loc[(base['PIB'] > 200000   )]
# Out:
#     CODIGO MUNICIPIO        PIB  VALOREMPENHO
# 49     149   TRIUNFO  223848.22    1442759.82
